# %% [markdown]
# <a href="https://colab.research.google.com/github/Samar-111/Smart-Garbage-Detection-system-using-computer-vision/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
